# %% [markdown]
# <a href="https://colab.research.google.com/github/SameehaSyed05/flyrank-ml-internshipp/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SameehaSyed05/flyrank-ml-internshipp/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Lane: Refresh / Content Opportunity Scoring.
#
# I chose this lane because it focuses on identifying which pages should be reviewed first for improvement. This can help prioritize pages that are more likely to benefit from updates instead of reviewing every page manually. Machine learning can assist by ranking pages based on observable search and content signals.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# Decision:
# This work helps determine which pages should be prioritized for content review and updates.
#
# Who acts on it?
# The SEO or content team uses the ranked list to decide which pages to review first.
#
# Action:
# The team reviews the selected pages and updates or improves their content based on the recommendations.
#
# Cost of a wrong recommendation:
# If the recommendation is wrong, important pages that need attention may be missed, while time and effort may be spent reviewing pages that do not require updates.
#
# Why data or ML can help:
# Machine learning can analyze multiple observable search and content signals together to rank pages for review more effectively than using simple manual rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
# The starter dataset contains 30,000 pages. The average number of impressions is 5200.37, and the average CTR is 0.51. These numbers show that the dataset contains enough search performance information to study which pages should be prioritized for content review and updates. The dataset provides a useful starting point for building and evaluating a content opportunity scoring approach.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
import pandas as pd

if not os.path.exists("/content/flyrank-ml-internshipp"):
    # !git clone https://github.com/SameehaSyed05/flyrank-ml-internshipp.git

df = pd.read_csv("/content/flyrank-ml-internshipp/data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Average impressions:", df["impressions_90d"].mean())
print("Average CTR:", df["ctr"].mean())
# Out:
# Number of pages: 30000
# Average impressions: 5200.3663
# Average CTR: 0.5107333333333334

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# MY WORK CAN SAY:
# My work can identify patterns in the available search and content data and rank pages that may be good candidates for content review. The results are intended to support the SEO or content team in deciding which pages to review first.
# MY WOKR CANNOT SAY:
# My work cannot prove that updating a page will improve its search performance. It also cannot predict Google's algorithm or guarantee that a recommendation will lead to better rankings or more traffic. The findings are based only on the available dataset and should be treated as decision support, not proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
